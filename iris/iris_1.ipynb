# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.heatmap(iris.corr())

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris, kind='reg')

# %%
iris_setosa=iris.loc[iris['species']=='setosa']
iris_versicolor=iris.loc[iris['species']=='versicolor']
iris_virginica=iris.loc[iris['species']=='virginica']

# %%
plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa["petal_length"]), 'o')
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor["petal_length"]), 'o')
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_virginica["petal_length"]), 'o')

# %%
plt.plot(iris_setosa["petal_width"],np.zeros_like(iris_setosa["petal_width"]), 'o')
plt.plot(iris_versicolor["petal_width"],np.zeros_like(iris_versicolor["petal_width"]), 'o')
plt.plot(iris_virginica["petal_width"],np.zeros_like(iris_virginica["petal_width"]), 'o')

# %%
plt.plot(iris_setosa["sepal_length"],np.zeros_like(iris_setosa["sepal_length"]), 'o')
plt.plot(iris_versicolor["sepal_length"],np.zeros_like(iris_versicolor["sepal_length"]), 'o')
plt.plot(iris_virginica["sepal_length"],np.zeros_like(iris_virginica["sepal_length"]), 'o')

# %%
plt.plot(iris_setosa["sepal_width"],np.zeros_like(iris_setosa["sepal_width"]), 'o')
plt.plot(iris_versicolor["sepal_width"],np.zeros_like(iris_versicolor["sepal_width"]), 'o')
plt.plot(iris_virginica["sepal_width"],np.zeros_like(iris_virginica["sepal_width"]), 'o')

# %%
iris.plot(kind="scatter",x="sepal_length",y="sepal_width")

# %%
sns.pairplot(iris,hue='species')

# %%
sns.FacetGrid(iris,hue="species") \
    .map(sns.distplot,"petal_length")

# %%
sns.FacetGrid(iris,hue="species",height=5) \
    .map(sns.distplot,"petal_width")

# %%
sns.FacetGrid(iris,hue="species",height=5) \
    .map(sns.distplot,"sepal_length")

# %%
sns.FacetGrid(iris,hue="species",height=5) \
    .map(sns.distplot,"sepal_width")

# %%
sns.boxplot(x='species',y='petal_length',data=iris)

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
